# %% [markdown]
# # Clustering

# %%
from sklearn.model_selection import LeaveOneOut
from sklearn.linear_model import LogisticRegression
from pandas import read_csv, melt
df = read_csv("./datasets/Group_A_B.csv")
df_long = melt(df, id_vars=None, value_vars=['NoProblem', 'Problem'], var_name='Group', value_name='Measure')

X = df_long["Measure"].values.reshape(-1, 1)
y = df_long["Group"]

# create the LOOCV iterator
loocv = LeaveOneOut()

# initialize the KMeans model
kmeans = KMeans(n_clusters=2)

# initialize an array to store the predictions
predictions = np.zeros(X.shape[0])

# iterate over the LOOCV splits
for train_index, test_index in loocv.split(X):
    # get the train and test data for this split
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # fit the model to the train data
    kmeans.fit(X_train)

    # predict the label for the test data
    predictions[test_index] = kmeans.predict(X_test)

# print the accuracy of the model
print("Accuracy:", np.mean(predictions == y))

# create a scatter plot to visualize the results
plt.scatter(y, X, c=predictions)
plt.show()
# Out:
# Accuracy: 0.0

# %%
from sklearn.cluster import KMeans
from sklearn.model_selection import LeaveOneOut
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt

# load the iris dataset
iris = datasets.load_iris()
X = iris.data
y = iris.target

# create the LOOCV iterator
loocv = LeaveOneOut()

# initialize the KMeans model
kmeans = KMeans(n_clusters=3)

# initialize an array to store the predictions
predictions = np.zeros(X.shape[0])

# iterate over the LOOCV splits
for train_index, test_index in loocv.split(X):
    # get the train and test data for this split
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # fit the model to the train data
    kmeans.fit(X_train)

    # predict the label for the test data
    predictions[test_index] = kmeans.predict(X_test)

# print the accuracy of the model
print("Accuracy:", np.mean(predictions == y))

# create a scatter plot to visualize the results
plt.scatter(X[:, 0], X[:, 1], c=predictions)
plt.show()
# Out:
# Accuracy: 0.3333333333333333

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(predictions, X)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.scatter(predictions, X)
#       3 plt.show()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2790, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2785 @_copy_docstring_and_deprecators(Axes.scatter)
#    2786 def scatter(
#    2787         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2788         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2789         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2790     __ret = gca().scatter(
#    2791         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2792         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
# ...
